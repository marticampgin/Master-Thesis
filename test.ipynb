# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('data/labeled data.xlsx')

# %%
df.drop(columns=['comment'], inplace=True)

# %%
mapping = {-1: 'Negative', 0: 'Neutral', 1: 'Positive'}

# %%
df['label'] = df['label'].map(mapping)

# %%
value_counts = df['label'].value_counts().to_dict()

# %%
value_counts
# Out:
# {'Neutral': 101, 'Positive': 96, 'Negative': 82}

# %%
labels = list(value_counts.keys())

# %%
counts = list(value_counts.values())

# %%
fig, ax = plt.subplots()
ax.pie(counts, labels=labels, autopct='%1.1f%%',
       colors=['royalblue', 'seagreen', 'indianred'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2a78e0a1490>,
#   <matplotlib.patches.Wedge at 0x2a78b3ed190>,
#   <matplotlib.patches.Wedge at 0x2a78e2ddcd0>],
#  [Text(0.4620718128500907, 0.9982432768465966, 'Neutral'),
#   Text(-1.0749213521322325, -0.23354675491261576, 'Positive'),
#   Text(0.6634793961562448, -0.8773796731610238, 'Negative')],
#  [Text(0.252039170645504, 0.5444963328254163, '36.2%'),
#   Text(-0.5863207375266721, -0.12738913904324495, '34.4%'),
#   Text(0.3618978524488608, -0.4785707308151039, '29.4%')])
