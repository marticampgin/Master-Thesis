# %%
import pandas as pd
import os

# %%
file_name = 'book1700k-1800k.csv'
folder_name = 'book_data'
books_df = pd.read_csv(os.path.join(folder_name, file_name))

# %%
books_df.head(10)
# Out:
#             Authors  CountsOfReview  \
# 0    Eleanor Updale               9
# 1    Jane E. Gerver               3
# 2  George M. Thomas               0
# 3     Ruthie Bolton              12
# 4    Maurice Rheims               0
# 5   Angela Orebaugh               0
# 6       Marty Noble               0
# 7        Éric Marty               0
# 8     Ewa Mazierska               0
# 9    Richard Taylor               0
#
#                                          Description        ISBN       Id  \
# 0  Montmorency, the man leading a double life, to...  0439606764  1700000
# 1  A classroom project teaches a little bear name...  0439283086  1700004
# 2  The authors show how the cultural values under...  0803928920  1700007
# 3  Ruthie Mae Bolton was born January 6, 1961, in...  0151001049  1700013
# 4                                                NaN  202019113X  1700014
# 5  <b>The Perfect Reference for the Multitasked S...  1597491705  1700016
# ...

# %%
books_df.shape
# Out:
# (32105, 19)

# %%
descriptions = books_df['Description'].tolist()

# %%
for desc in descriptions[:100]:
    print(desc, end="\n===========\n")
# Out:
# Montmorency, the man leading a double life, torn between his two identities, returns in this gripping sequel.<br /><br />Five years after giving up his life of crime in the sewers, Montmorency is back in London. But his evil alter ego, Scarper has returned too, pulling him back into a dark world of crime.<br /><br />Montmorency's old friend and fellow government agent, Lord George Fox-Selwyn, fights to rescue him from disaster and risks calling in Montmorency's prison doctor, Robert Farcett, to help.<br /><br />However, when Montmorency turns up on a Scottish Island, he finds himself caught in another web of mystery.
# ...
